# %%
test2

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import pysal as ps
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from math import ceil
from pandas import * 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
# Out:
# /Users/axleabner/opt/anaconda3/lib/python3.8/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.9.0-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
line1= pd.read_csv(f'corline1.csv',error_bad_lines=False)

# %%
line2= pd.read_csv(f'corline2.csv',error_bad_lines=False)

# %%
gdf = gpd.read_file(f"mapNYC.shp")
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    263 non-null    int64
#  1   Shape_Leng  263 non-null    float64
#  2   Shape_Area  263 non-null    float64
#  3   zone        263 non-null    object
#  4   LocationID  263 non-null    int64
#  5   borough     263 non-null    object
#  6   geometry    263 non-null    geometry
# dtypes: float64(2), geometry(1), int64(2), object(2)
# memory usage: 14.5+ KB

# %%
line1
# Out:
#        Unnamed: 0      xcoord_x     ycoord_x     xcoord_y     ycoord_y
# 0               0  9.359968e+05  191376.7495  935996.8210  191376.7495
# 1               1  9.981422e+05  191215.0684  935996.8210  191376.7495
# 2               2  9.938073e+05  231458.3761  935996.8210  191376.7495
# 3               3  9.881012e+05  189071.5791  935996.8210  191376.7495
# 4               4  9.855671e+05  192774.4924  935996.8210  191376.7495
# ...           ...           ...          ...          ...          ...
# 23123       23123  1.022197e+06  213491.2335  964319.7354  157998.9356
# 23124       23124  9.558542e+05  172088.0924  964319.7354  157998.9356
# 23125       23125  9.598640e+05  164432.1129  955698.9158  168837.0586
# 23126       23126  9.967877e+05  218166.4344  926485.9390  136202.9857
# 23127       23127  1.025565e+06  247818.5882  926485.9390  136202.9857
#
# [23128 rows x 5 columns]

# %%
line2
# Out:
#        Unnamed: 0      xcoord_x     ycoord_x      xcoord_y     ycoord_y
# 0               0  9.359968e+05  191376.7495  9.359968e+05  191376.7495
# 1               1  9.881012e+05  189071.5791  9.359968e+05  191376.7495
# 2               2  9.855671e+05  192774.4924  9.359968e+05  191376.7495
# 3               3  9.977346e+05  232321.2905  9.359968e+05  191376.7495
# 4               4  1.000644e+06  237395.8715  9.359968e+05  191376.7495
# ...           ...           ...          ...           ...          ...
# 18345       18345  9.992721e+05  227103.7596  9.318714e+05  140681.3514
# 18346       18346  9.378132e+05  169286.1507  9.193257e+05  130813.7173
# 18347       18347  1.008206e+06  185807.8688  1.032418e+06  166735.0795
# 18348       18348  1.003140e+06  190001.9667  1.032418e+06  166735.0795
# 18349       18349  9.953659e+05  198271.7997  9.320765e+05  131946.8866
#
# [18350 rows x 5 columns]

# %%
x1 = line2.xcoord_x
x2 = line2.ycoord_x
y1 = line2.xcoord_y
y2 = line2.ycoord_y

# %%
f = plt.figure()

ax1 = f.add_subplot()
plt.plot([x1,y1],[x2,y2], 'c-', alpha=0.002)
gdf.plot(legend=True, color = "0",figsize=(12,6), alpha=0.1, ax=ax1)
plt.grid(False)

plt.show()
plt.savefig('NYCaf.png', dpi=300)

# %%
x01 = line1.xcoord_x
x02 = line1.ycoord_x
y01 = line1.xcoord_y
y02 = line1.ycoord_y

# %%
f = plt.figure()
f.set_size_inches(12,7)
ax1 = f.add_subplot()
plt.plot([x01,y01],[x02,y02], 'm-',alpha=0.002)
plt.plot([x01,y01],[x02,y02], 'c-', alpha=0.002)
gdf.plot(legend=True, color = "0",figsize=(12,6), alpha=0.1, ax=ax1)
plt.grid(False)

plt.show()
plt.savefig('NYCpre.png', dpi=150)

# %%
f,axes = plt.subplots(1,2,figsize=(24,12))

ax1 = f.add_subplot()

plt.plot([x01,y01],[x02,y02], 'm-',alpha=0.002)
plt.plot([x01,y01],[x02,y02], 'c-', alpha=0.002)
gdf.plot(legend=True, color = "0", alpha=0.1, ax=ax1)

plt.grid(False)



ax2 = f.add_subplot()

plt.plot([x1,y1],[x2,y2], 'm-',alpha=0.002)
plt.plot([x1,y1],[x2,y2], 'c-', alpha=0.002)
gdf.plot(legend=True, color = "0",alpha=0.1, ax=ax2)
plt.grid(False)

for ax in axes:
    ax.axis('off')
    
axes[1].set_title('Pre-COVID', size=20)
axes[2].set_title('After_COVID', size=20)
    
    
    
plt.savefig('test.png', dpi=150)
# Out:
# <ipython-input-13-4b4853f53447>:13: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax2 = f.add_subplot()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-4b4853f53447> in <module>
#      22
#      23 axes[1].set_title('Pre-COVID', size=20)
# ---> 24 axes[2].set_title('After_COVID', size=20)
#      25
#      26
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
f = plt.figure()
f.set_size_inches(12,7)
ax1 = f.add_subplot()
plt.plot([x1,y1],[x2,y2], 'm-',alpha=0.002)
plt.plot([x1,y1],[x2,y2], 'c-', alpha=0.002)
gdf.plot(legend=True, color = "0",figsize=(12,6), alpha=0.1, ax=ax1)
plt.grid(False)

plt.show()
# Out:
# /Users/axleabner/opt/anaconda3/lib/python3.8/site-packages/geopandas/plotting.py:641: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(

# %%
f = plt.figure()
f.set_size_inches(12,7)
ax1 = f.add_subplot()
plt.plot([x01,y01],[x02,y02], 'm-',alpha=0.002)
gdf.plot(legend=True, color = "0",figsize=(12,6), alpha=0.1, ax=ax1)
plt.grid(False)

plt.show()

# %%
f = plt.figure()
f.set_size_inches(12,7)
ax1 = f.add_subplot()
plt.plot([x1,y1],[x2,y2], 'm-',alpha=0.002)
plt.plot([x1,y1],[x2,y2], 'c-', alpha=0.002)
gdf.plot(column='borough',legend=True, color = "0.4",figsize=(12,6), alpha=1, ax=ax1)
plt.grid(False)

plt.show()
# Out:
# /Users/axleabner/opt/anaconda3/lib/python3.8/site-packages/geopandas/plotting.py:641: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(

# %%
gdf.head()
# Out:
#    OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0         1    0.116357    0.000782           Newark Airport           1
# 1         2    0.433470    0.004866              Jamaica Bay           2
# 2         3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3         4    0.043567    0.000112            Alphabet City           4
# 4         5    0.092146    0.000498            Arden Heights           5
#
#          borough                                           geometry
# 0            EWR  POLYGON ((933100.918 192536.086, 933091.011 19...
# 1         Queens  MULTIPOLYGON (((1033269.244 172126.008, 103343...
# 2          Bronx  POLYGON ((1026308.770 256767.698, 1026495.593 ...
# 3      Manhattan  POLYGON ((992073.467 203714.076, 992068.667 20...
# 4  Staten Island  POLYGON ((935843.310 144283.336, 936046.565 14...

# %%
f = plt.figure()
f.set_size_inches(12,7)
ax1 = f.add_subplot()

gdf.plot(column='zone',legend=True, color = "0.4",figsize=(12,6), alpha=0.8, ax=ax1)
plt.grid(False)

plt.show()
# Out:
# /Users/axleabner/opt/anaconda3/lib/python3.8/site-packages/geopandas/plotting.py:641: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
plt.plot([x1,y1],[x2,y2], 'm-', alpha=0.002)
plt.plot([x1,y1],[x2,y2], 'c-', alpha=0.002)

plt.show()

# %%
line2.xcoord_x.plot.hist(bins=150)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
line2.ycoord_x.plot.hist(bins=150)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
line2.xcoord_y.plot.hist(bins=150)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
line2.ycoord_y.plot.hist(bins=150)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [18.50, 13.50]
plt.rcParams["figure.autolayout"] = True
x = np.linspace(-10, 10, 50)
y = np.sin(x)
plt.axhline(y=0, c="green", linestyle="dashdot", label="y=0")
plt.plot(x, y, c="red", lw=2, linestyle="dashdot", label="y=sin(x)")
plt.grid(False)
plt.axis('off')
plt.legend()
plt.show()
